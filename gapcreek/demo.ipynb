# %%
from camera_utils import CameraView
import cv2
import matplotlib.pyplot as plt

# %%
camera = CameraView('1a.xml')
image = cv2.imread('1A_input_test.jpg')
camera.poly_point(image)
plt.imshow(image[:,:,::-1])
#print(image.shape)
#camera.project(270, 320)
# Out:
# test delete later..:view_tranformer it.

# %%
camera = CameraView('1a.xml')
image = cv2.imread('1A_input_test.jpg')
image = camera.sanity_check(image)
plt.imshow(image[:,:,::-1])
plt.axis('off')

# %%
xw, yw = camera.project(270, 320)
print(xw, yw)
xw, yw = camera.project(335, 212)
print(xw, yw)
xw, yw = camera.project(402, 164)
print(xw, yw)
xw, yw = camera.project(432, 124)
print(xw, yw)
xw, yw = camera.project(463, 97)
print(xw, yw)
xw, yw = camera.project(492, 82)
print(xw, yw)

# %%
camera = CameraView('1b.xml')
image = cv2.imread('1B_input_test.jpg')
image = camera.sanity_check(image)
plt.imshow(image[:,:,::-1])
plt.axis('off')

# %%
import cv2
def mouse_callback(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print(f"Clicked point - x: {x}, y: {y}")

# Load the image
image = cv2.imread('1B_test_input_image.jpg')

# Create a named window for the image
cv2.namedWindow('Image')

# Set the mouse callback function for the window
cv2.setMouseCallback('Image', mouse_callback)

# Display the image
cv2.imshow('Image', image)
# Wait for the user to click points and press 'Esc' to exit
while True:
    key = cv2.waitKey(1)
    if key == 27:  # Esc key
        break

# Close all windows
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 16
#      13 cv2.setMouseCallback('Image', mouse_callback)
#      15 # Display the image
# ---> 16 cv2.imshow('Image', image)
#      17 # Wait for the user to click points and press 'Esc' to exit
#      18 while True:
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:971: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
